# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'/content/Final_Data.csv')
df
# Out:
#       Unnamed: 0        Date          Open          High           Low  \
# 0              0  2016-11-01   8653.150391   8669.599609   8614.500000
# 1              1  2016-11-02   8542.799805   8549.500000   8504.849609
# 2              2  2016-11-03   8499.849609   8537.650391   8476.150391
# 3              3  2016-11-04   8503.599609   8504.000000   8400.250000
# 4              4  2016-11-07   8535.750000   8535.849609   8481.450195
# ...          ...         ...           ...           ...           ...
# 1682        1682  2023-08-24  19535.150391  19584.449219  19369.000000
# 1683        1683  2023-08-25  19297.400391  19339.550781  19229.699219
# 1684        1684  2023-08-28  19298.349609  19366.849609  19249.699219
# 1685        1685  2023-08-29  19374.849609  19377.900391  19309.099609
# 1686        1686  2023-08-30  19433.449219  19452.800781  19334.750000
#
#              Close     Adj Close    Volume         MA_50        MA_100  \
# ...

# %%
df2=df[["MA_50",'MA_100','MA_200','Close_diff','RSI','RSI_CAT','SO(%K)','EMA_50','EMA_200','SO_%D','SO(%K)_CAT']]

# %%
df2=df2.iloc[:len(df2)-1,:]

# %%
df2
# Out:
#              MA_50        MA_100        MA_200  Close_diff        RSI  \
# 0      8710.285039   8556.721025   8073.934006  -26.900391  55.986634
# 1      8708.084043   8559.653027   8077.799006  -28.799805  55.702971
# 2      8704.318047   8562.492031   8082.382258  -14.899414  56.411570
# 3      8699.655039   8564.165029   8086.544258  -69.849609  58.210359
# 4      8697.013027   8566.405029   8091.210256  -38.700195  56.423904
# ...            ...           ...           ...         ...        ...
# 1681  19351.350156  18715.369629  18333.965059    4.800781  38.594112
# 1682  19364.761133  18739.719629  18340.635059 -148.451172  37.784370
# 1683  19374.959141  18761.570645  18346.378311  -31.599610  39.943467
# 1684  19387.318164  18781.033652  18351.894561    7.701172  36.608153
# 1685  19397.651172  18800.479648  18357.822812  -32.199218  40.387748
#
#        RSI_CAT     SO(%K)        EMA_50       EMA_200      SO_%D  SO(%K)_CAT
# ...

# %%
X=df.iloc[:len(df)-1,[2,5]]

# %%
X=pd.concat([X,df2],axis=1)

# %%
X
# Out:
#               Open         Close         MA_50        MA_100        MA_200  \
# 0      8653.150391   8626.250000   8710.285039   8556.721025   8073.934006
# 1      8542.799805   8514.000000   8708.084043   8559.653027   8077.799006
# 2      8499.849609   8484.950195   8704.318047   8562.492031   8082.382258
# 3      8503.599609   8433.750000   8699.655039   8564.165029   8086.544258
# 4      8535.750000   8497.049805   8697.013027   8566.405029   8091.210256
# ...            ...           ...           ...           ...           ...
# 1681  19439.199219  19444.000000  19351.350156  18715.369629  18333.965059
# 1682  19535.150391  19386.699219  19364.761133  18739.719629  18340.635059
# 1683  19297.400391  19265.800781  19374.959141  18761.570645  18346.378311
# 1684  19298.349609  19306.050781  19387.318164  18781.033652  18351.894561
# 1685  19374.849609  19342.650391  19397.651172  18800.479648  18357.822812
#
# ...

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

# %%
X['RSI_CAT'].value_counts()
# Out:
# Balanced      1598
# OverBought      50
# OverSold        38
# Name: RSI_CAT, dtype: int64

# %%
X['SO(%K)_CAT']= label_encoder.fit_transform(X['SO(%K)_CAT'])
X['RSI_CAT']= label_encoder.fit_transform(X['RSI_CAT'])

# %%
X
# Out:
#               Open         Close         MA_50        MA_100        MA_200  \
# 0      8653.150391   8626.250000   8710.285039   8556.721025   8073.934006
# 1      8542.799805   8514.000000   8708.084043   8559.653027   8077.799006
# 2      8499.849609   8484.950195   8704.318047   8562.492031   8082.382258
# 3      8503.599609   8433.750000   8699.655039   8564.165029   8086.544258
# 4      8535.750000   8497.049805   8697.013027   8566.405029   8091.210256
# ...            ...           ...           ...           ...           ...
# 1681  19439.199219  19444.000000  19351.350156  18715.369629  18333.965059
# 1682  19535.150391  19386.699219  19364.761133  18739.719629  18340.635059
# 1683  19297.400391  19265.800781  19374.959141  18761.570645  18346.378311
# 1684  19298.349609  19306.050781  19387.318164  18781.033652  18351.894561
# 1685  19374.849609  19342.650391  19397.651172  18800.479648  18357.822812
#
# ...

# %%
y=df.iloc[1:,2].reset_index().drop("index",axis=1)

# %%
y
# Out:
#               Open
# 0      8542.799805
# 1      8499.849609
# 2      8503.599609
# 3      8535.750000
# 4      8540.000000
# ...            ...
# 1681  19535.150391
# 1682  19297.400391
# 1683  19298.349609
# 1684  19374.849609
# 1685  19433.449219
#
# [1686 rows x 1 columns]

# %%
from matplotlib import pyplot as plt
y['Open'].plot(kind='line', figsize=(8, 4), title='Open')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
x1=[i for i in range(1686)]
y1=y['Open']
plt.plot(y1)
plt.show()

# %%
len(pred1)
# Out:
# 557

# %%
len(y1)
# Out:
# 1686

# %%
plt.plot(pred1)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, RidgeCV, Lasso

# %% [markdown]
# MODELS FOR OPEN

# %%
model1 = LinearRegression()
model1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred1=model1.predict(X_test)

# %%
plt.plot(y_test)
plt.plot(pred1)
plt.show()

# %%
plt.plot(y_test)
plt.plot(pred4)
plt.show()

# %%
lasso_model = Lasso(alpha=170)
lasso_model.fit(X_train , y_train)
# Out:
# Lasso(alpha=170)

# %%
pred2 = lasso_model.predict(X_test)

# %%
from sklearn.tree import DecisionTreeRegressor
decision_regressor = DecisionTreeRegressor(random_state=0)
decision_regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
pred3 = decision_regressor.predict(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor(max_depth=2, random_state=0)
regr.fit(X_train, y_train)
# Out:
# <ipython-input-279-80b3646e1551>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regr.fit(X_train, y_train)
# RandomForestRegressor(max_depth=2, random_state=0)

# %%
pred4 = regr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
import math

# %%
mse = mean_squared_error(y_test, pred1)
rmse = math.sqrt(mse)
rmse
# Out:
# 81.44995430094522

# %%
mse = mean_squared_error(y_test, pred2)
rmse = math.sqrt(mse)
rmse
# Out:
# 81.25786579917587

# %%
mse = mean_squared_error(y_test, pred3)
rmse = math.sqrt(mse)
rmse
# Out:
# 115.76318852787448

# %%
mse = mean_squared_error(y_test, pred4)
rmse = math.sqrt(mse)
rmse
# Out:
# 674.7421922407748

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test, pred1)
print("R-squared (R2) score for open prices using Linear_regression :", r2)

r2_lasso = r2_score(y_test, pred2)
print("R-squared (R2) score for open prices using Lasso_regression :", r2_lasso)

decision_tree_r2= r2_score(y_test, pred3)
print("R-squared (R2) score for open prices using decisiontree_regression :", decision_tree_r2)

random_forest_r2 = r2_score(y_test, pred4)
print("R-squared (R2) score for open prices using randomforest_regression :", random_forest_r2)
# Out:
# R-squared (R2) score for open prices using Linear_regression : 0.9994284034705543
# R-squared (R2) score for open prices using Lasso_regression : 0.9994310963548217
# R-squared (R2) score for open prices using decisiontree_regression : 0.9988453540041075
# R-squared (R2) score for open prices using randomforest_regression : 0.9607731324603965

# %%
pred1.shape
# Out:
# (557, 1)

# %%
pred2=pred2.reshape((557,1))
pred3= pred3.reshape((557,1))
pred4 = pred4.reshape((557,1))

# %%
absolute_percentage_errors = np.abs((y_test - pred1) / y_test)
mape = np.mean(absolute_percentage_errors) * 100
print("Mean Absolute Percentage Error (MAPE) for Linear_regression:", mape, "%")

lasso_absolute_percentage_errors = np.abs((y_test - pred2) / y_test)
mape = np.mean(lasso_absolute_percentage_errors) * 100
print("Mean Absolute Percentage Error (MAPE) for Lasso_regression:", mape, "%")

decision_tree_absolute_percentage_errors = np.abs((y_test - pred3) / y_test)
mape = np.mean(decision_tree_absolute_percentage_errors) * 100
print("Mean Absolute Percentage Error (MAPE) for decision_tree_regression:", mape, "%")

random_forest_absolute_percentage_errors = np.abs((y_test - pred4) / y_test)
mape = np.mean(random_forest_absolute_percentage_errors) * 100
print("Mean Absolute Percentage Error (MAPE) for random_forest_regression:", mape, "%")
# Out:
# Mean Absolute Percentage Error (MAPE) for Linear_regression: Open    0.381774
# dtype: float64 %
# Mean Absolute Percentage Error (MAPE) for Lasso_regression: Open    0.367309
# dtype: float64 %
# Mean Absolute Percentage Error (MAPE) for decision_tree_regression: Open    0.601967
# dtype: float64 %
# Mean Absolute Percentage Error (MAPE) for random_forest_regression: Open    4.280313
# dtype: float64 %
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
# ...

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
open_MAE = mean_absolute_percentage_error(y_test, pred1)
print('MAE for open prices is :'+str(open_MAE))
# Out:
# MAE for open prices is :0.0038177358226043454

# %%
open_MAE = mean_absolute_percentage_error(y_test, pred2)
print('MAE for open prices is :'+str(open_MAE))
# Out:
# MAE for open prices is :0.0036730931483147148

# %%
open_MAE = mean_absolute_percentage_error(y_test, pred3)
print('MAE for open prices is :'+str(open_MAE))
# Out:
# MAE for open prices is :0.006019673560707543

# %%
open_MAE = mean_absolute_percentage_error(y_test, pred4)
print('MAE for open prices is :'+str(open_MAE))
# Out:
# MAE for open prices is :0.04280312759920601

# %%
#################################
today_open=model1.predict(X)
data_frame=pd.DataFrame(today_open,columns=["New_open"])

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.scatter(y_test, pred1, color='red', label='Actual vs Predicted')
plt.plot([i for i in range(20000)])
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Scatter Plot of Actual vs Predicted Values')

# Display a legend
plt.legend()

# Show the plot
plt.show()

# %%
plt.scatter(y_test, pred2, color='b', label='Actual vs Predicted')
# Add labels and a title
plt.plot([i for i in range(20000)])
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Scatter Plot of Actual vs Predicted Values')

# Display a legend
plt.legend()

# Show the plot
plt.show()

# %%
plt.scatter(y_test, pred3, color='g', label='Actual vs Predicted')
# Add labels and a title
plt.plot([i for i in range(20000)])
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Scatter Plot of Actual vs Predicted Values')

# Display a legend
plt.legend()

# Show the plot
plt.show()

# %%
plt.scatter(y_test, pred4, color='b', label='Actual vs Predicted')
# Add labels and a title
plt.plot([i for i in range(20000)])
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Scatter Plot of Actual vs Predicted Values')

# Display a legend
plt.legend()

# Show the plot
plt.show()

# %%
df1=df["Close"][:len(df)-1].to_frame()

# %%
df1
# Out:
#              Close
# 0      8626.250000
# 1      8514.000000
# 2      8484.950195
# 3      8433.750000
# 4      8497.049805
# ...            ...
# 1681  19444.000000
# 1682  19386.699219
# 1683  19265.800781
# 1684  19306.050781
# 1685  19342.650391
#
# [1686 rows x 1 columns]

# %%
data_frame=pd.concat([data_frame,df1,df2],axis=1)

# %%
data_frame.drop("Close",axis=1,inplace=True)

# %%
X1=data_frame

# %%
X1
# Out:
#           New_open         MA_50        MA_100        MA_200  Close_diff  \
# 0      8599.070952   8710.285039   8556.721025   8073.934006  -26.900391
# 1      8493.377708   8708.084043   8559.653027   8077.799006  -28.799805
# 2      8468.738287   8704.318047   8562.492031   8082.382258  -14.899414
# 3      8416.829939   8699.655039   8564.165029   8086.544258  -69.849609
# 4      8476.434754   8697.013027   8566.405029   8091.210256  -38.700195
# ...            ...           ...           ...           ...         ...
# 1681  19455.230131  19351.350156  18715.369629  18333.965059    4.800781
# 1682  19399.958921  19364.761133  18739.719629  18340.635059 -148.451172
# 1683  19315.112006  19374.959141  18761.570645  18346.378311  -31.599610
# 1684  19343.531843  19387.318164  18781.033652  18351.894561    7.701172
# 1685  19380.654433  19397.651172  18800.479648  18357.822812  -32.199218
#
#             RSI   RSI_CAT     SO(%K)        EMA_50       EMA_200      SO_%D  \
# ...

# %%
from matplotlib import pyplot as plt
X1['New_open'].plot(kind='line', figsize=(8, 4), title='open')
df1['Close'].plot(kind='line', figsize=(8, 4), title='Close')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
X1['RSI_CAT'].value_counts()
# Out:
# Balanced      1598
# OverBought      50
# OverSold        38
# Name: RSI_CAT, dtype: int64

# %%
X1['SO(%K)_CAT']= label_encoder.fit_transform(X1['SO(%K)_CAT'])
X1['RSI_CAT']= label_encoder.fit_transform(X1['RSI_CAT'])

# %%
X1
# Out:
#           New_open         MA_50        MA_100        MA_200  Close_diff  \
# 0      8599.070952   8710.285039   8556.721025   8073.934006  -26.900391
# 1      8493.377708   8708.084043   8559.653027   8077.799006  -28.799805
# 2      8468.738287   8704.318047   8562.492031   8082.382258  -14.899414
# 3      8416.829939   8699.655039   8564.165029   8086.544258  -69.849609
# 4      8476.434754   8697.013027   8566.405029   8091.210256  -38.700195
# ...            ...           ...           ...           ...         ...
# 1681  19455.230131  19351.350156  18715.369629  18333.965059    4.800781
# 1682  19399.958921  19364.761133  18739.719629  18340.635059 -148.451172
# 1683  19315.112006  19374.959141  18761.570645  18346.378311  -31.599610
# 1684  19343.531843  19387.318164  18781.033652  18351.894561    7.701172
# 1685  19380.654433  19397.651172  18800.479648  18357.822812  -32.199218
#
#             RSI  RSI_CAT     SO(%K)        EMA_50       EMA_200      SO_%D  \
# ...

# %%
y1=df["Close"][1:].to_frame()

# %%
y1
# Out:
#              Close
# 1      8514.000000
# 2      8484.950195
# 3      8433.750000
# 4      8497.049805
# 5      8543.549805
# ...            ...
# 1682  19386.699219
# 1683  19265.800781
# 1684  19306.050781
# 1685  19342.650391
# 1686  19347.449219
#
# [1686 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.33,random_state=42)

# %% [markdown]
#  MODELS FOR CLOSE PREDICTIONS
#
#
#  .

# %%
model2 = LinearRegression()
model2.fit(X_train,y_train)
pred2=model2.predict(X_test)

# %%
lasso_model = Lasso(alpha=170)
lasso_model.fit(X_train , y_train)
# Out:
# Lasso(alpha=170)

# %%
lasso_pred = lasso_model.predict(X_test)

# %%
from sklearn.tree import DecisionTreeRegressor
decision_regressor = DecisionTreeRegressor(random_state=0)
decision_regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
decision_pred = decision_regressor.predict(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor(max_depth=2, random_state=0)
regr.fit(X_train, y_train)
# Out:
# <ipython-input-320-80b3646e1551>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regr.fit(X_train, y_train)
# RandomForestRegressor(max_depth=2, random_state=0)

# %%
random_pred = regr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
import math

# %%
mse = mean_squared_error(y_test, pred2)
rmse = math.sqrt(mse)
rmse
# Out:
# 133.88679426033158

# %%
mse = mean_squared_error(y_test, lasso_pred)
rmse = math.sqrt(mse)
rmse
# Out:
# 133.76386426644117

# %%
mse = mean_squared_error(y_test, decision_pred)
rmse = math.sqrt(mse)
rmse
# Out:
# 185.13144075075394

# %%
mse = mean_squared_error(y_test, random_pred)
rmse = math.sqrt(mse)
rmse
# Out:
# 690.5630068500423

# %%
#################################
today_close=model2.predict(X1)

# %%
data_frame1=pd.DataFrame(today_close,columns=["New_close"])

# %%
data_frame1
# Out:
#          New_close
# 0      8553.727155
# 1      8430.901832
# 2      8407.515398
# 3      8360.052445
# 4      8425.398775
# ...            ...
# 1681  19435.882843
# 1682  19393.869132
# 1683  19327.160910
# 1684  19354.986374
# 1685  19398.404654
#
# [1686 rows x 1 columns]

# %%
X1.shape==y1.shape
# Out:
# False

# %%
print(X1.shape)
print(y1.shape)
# Out:
# (1686, 12)
# (1686, 1)

# %%
new_data=pd.concat([data_frame["New_open"],data_frame1,df.iloc[:len(df)-1,[2,5]]],axis=1)

# %%
new_data
# Out:
#           New_open     New_close          Open         Close
# 0      8599.070952   8553.727155   8653.150391   8626.250000
# 1      8493.377708   8430.901832   8542.799805   8514.000000
# 2      8468.738287   8407.515398   8499.849609   8484.950195
# 3      8416.829939   8360.052445   8503.599609   8433.750000
# 4      8476.434754   8425.398775   8535.750000   8497.049805
# ...            ...           ...           ...           ...
# 1681  19455.230131  19435.882843  19439.199219  19444.000000
# 1682  19399.958921  19393.869132  19535.150391  19386.699219
# 1683  19315.112006  19327.160910  19297.400391  19265.800781
# 1684  19343.531843  19354.986374  19298.349609  19306.050781
# 1685  19380.654433  19398.404654  19374.849609  19342.650391
#
# [1686 rows x 4 columns]

# %%
pred_close=pd.DataFrame(pred2,columns=["Close"])

# %%
pred_close
# Out:
#             Close
# 0    10391.197547
# 1    17149.608115
# 2     9903.466547
# 3    11935.552323
# 4    10728.527648
# ..            ...
# 552   9974.947688
# 553   9381.615177
# 554  10886.210445
# 555  10070.571452
# 556  15865.677191
#
# [557 rows x 1 columns]

# %%
y_test=y_test.reset_index()

# %%
y_test.drop("index",axis=1,inplace=True)

# %%
max(abs(pred_close["Close"]-y_test["Close"]))
# Out:
# 1098.7473169024506

# %%
new_data.to_csv("Today_data.csv")

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

corr_matrix = new_data.corr()
plt.figure(figsize=(5, 5))
sn.heatmap(corr_matrix, annot=True)
plt.show()

# %%
r2 = r2_score(y_test, pred2)
print("R-squared (R2) score for linear close prices :", r2)

lasso_r2 = r2_score(y_test, lasso_pred)
print("R-squared (R2) score for lasso close prices :", lasso_r2)

decision_r2 = r2_score(y_test, decision_pred)
print("R-squared (R2) score for decision tree close prices :", decision_r2)

random_r2 = r2_score(y_test, random_pred)
print("R-squared (R2) score for random forest close prices :", r2)
# Out:
# R-squared (R2) score for linear close prices : 0.9984564950298298
# R-squared (R2) score for lasso close prices : 0.9984593281090742
# R-squared (R2) score for decision tree close prices : 0.9970488389658161
# R-squared (R2) score for random forest close prices : 0.9984564950298298

# %%
lasso_pred=lasso_pred.reshape((557,1))
decision_pred= decision_pred.reshape((557,1))
random_pred = random_pred.reshape((557,1))

# %%
absolute_percentage_errors = np.abs((y_test - pred2) / y_test)
mape = np.mean(absolute_percentage_errors) * 100
print("Mean Absolute Percentage Error (MAPE) for linear model:", mape, "%")

lasso_absolute_percentage_errors = np.abs((y_test - lasso_pred) / y_test)
mape = np.mean(lasso_absolute_percentage_errors) * 100
print("Mean Absolute Percentage Error (MAPE) for lasso model:", mape, "%")

decision_absolute_percentage_errors = np.abs((y_test - decision_pred) / y_test)
mape = np.mean(decision_absolute_percentage_errors) * 100
print("Mean Absolute Percentage Error (MAPE) for decision tree:", mape, "%")

random_absolute_percentage_errors = np.abs((y_test - random_pred) / y_test)
mape = np.mean(random_absolute_percentage_errors) * 100
print("Mean Absolute Percentage Error (MAPE) for random forest:", mape, "%")
# Out:
# Mean Absolute Percentage Error (MAPE) for linear model: Close    0.714672
# dtype: float64 %
# Mean Absolute Percentage Error (MAPE) for lasso model: Close    0.709667
# dtype: float64 %
# Mean Absolute Percentage Error (MAPE) for decision tree: Close    0.97063
# dtype: float64 %
# Mean Absolute Percentage Error (MAPE) for random forest: Close    4.489263
# dtype: float64 %
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
# ...

# %%
open_MAE = mean_absolute_percentage_error(y_test, pred2)
print('MAE for close prices is :'+str(open_MAE))

lasso_open_MAE = mean_absolute_percentage_error(y_test, lasso_pred)
print('MAE for close prices is :'+str(lasso_open_MAE))

decision_open_MAE = mean_absolute_percentage_error(y_test, decision_pred)
print('MAE for close prices is :'+str(decision_open_MAE))

random_open_MAE = mean_absolute_percentage_error(y_test, random_pred)
print('MAE for close prices is :'+str(random_open_MAE))
# Out:
# MAE for close prices is :0.007146720887359022
# MAE for close prices is :0.0070966653071029995
# MAE for close prices is :0.009706299004904554
# MAE for close prices is :0.04489262714688653

# %%
plt.scatter(y_test, pred2, color='b', label='Actual vs Predicted')
# Add labels and a title
plt.plot([i for i in range(20000)])
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Scatter Plot of Actual vs Predicted Values')

# Display a legend
plt.legend()

# Show the plot
plt.show()

# %%
plt.scatter(y_test, lasso_pred, color='r', label='Actual vs Predicted')
# Add labels and a title
plt.plot([i for i in range(20000)])
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Scatter Plot of Actual vs Predicted Values')

# Display a legend
plt.legend()

# Show the plot
plt.show()

# %%
plt.scatter(y_test, decision_pred, color='y', label='Actual vs Predicted')
# Add labels and a title
plt.plot([i for i in range(20000)])
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Scatter Plot of Actual vs Predicted Values')

# Display a legend
plt.legend()

# Show the plot
plt.show()

# %%
plt.scatter(y_test, random_pred, color='g', label='Actual vs Predicted')
# Add labels and a title
plt.plot([i for i in range(20000)])
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Scatter Plot of Actual vs Predicted Values')

# Display a legend
plt.legend()

# Show the plot
plt.show()
